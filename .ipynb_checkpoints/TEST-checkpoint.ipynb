# %%
import torch
import math
import matplotlib.pyplot as plt

import Modules
import Sequential
import Optimizer

def generate_disc_set(nb_sample):
    
    data = torch.empty(nb_sample, 2).uniform_(0, 1)
    labels = data.sub(0.5).pow(2).sum(1).sub(1/(2*math.pi)).sign().add(1).div(2).long()
    
    data_out = data[torch.where(labels==1)]
    data_in = data[torch.where(labels==0)]
    
    plt.figure(figsize=(6,6))
    plt.scatter(data_out[:,0],data_out[:,1])
    plt.scatter(data_in[:,0], data_in[:,1])

    return data, labels

data, target = generate_disc_set(1000)

# %%
m = Modules.Linear(2,20)
op = m(data)
print(op.size())

b = Modules.ReLu()
print(b(op).size())
# Out:
# torch.Size([1000, 20])
# torch.Size([1000, 20])

# %%
# Train :

nb_epochs = 25
losses = []

m1 = Modules.Linear(2,25)
m2 = Modules.Linear(25,25)
m3 = Modules.Linear(25,25)
m4 = Modules.Linear(25,2)
relu = Modules.ReLu()
MSE = Modules.MSE()
for e in range(nb_epochs):
    
    output = relu(m4(relu(m2(relu(m1(data))))))
    loss = MSE(output,target)
    print(loss)
# Out:
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)
# tensor(814.8957)

# %%
print(m2.params())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-ce3365034b58> in <module>()
# ----> 1 print(m2.params())
#
# C:\Users\richi\Documents\EPFL\Master\MA4\Deep Learning\Mini_project\project2\dl_project2\Modules.py in params(self)
#      39
#      40     def param(self):
# ---> 41         return torch.Tensor([self.w,self.dw,self.b,self.db])
#      42
#      43     def zero_grad(self):
#
# ValueError: only one element tensors can be converted to Python scalars

# %%
nb_epochs = 25
mini_batch_size = 200

model = Sequential.Sequential(m1,relu,m2,relu,m3,relu,m4,relu)
for e in range(nb_epochs):
    for b in range(0,data.size(0),mini_batch_size):
        output = model(data.narrow(0,b,mini_batch_size))
        loss = MSE(output,target.narrow(0,b,mini_batch_size))
        model.zero_grad()
        print(model.param())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-50417c5fc914> in <module>()
#       2 mini_batch_size = 200
#       3
# ----> 4 model = Sequential.Sequential(m1,relu,m2,relu,m3,relu,m4,relu)
#       5 for e in range(nb_epochs):
#       6     for b in range(0,data.size(0),mini_batch_size):
#
# C:\Users\richi\Documents\EPFL\Master\MA4\Deep Learning\Mini_project\project2\dl_project2\Sequential.py in __init__(self, *Modules)
#      15         for mod in Modules:
#      16             self.members.append(mod)
# ---> 17             self.parameters.append(mod.param())
#      18         self.memory = []
#      19         self.lossmemory = []
#
# AttributeError: 'Sequential' object has no attribute 'parameters'
