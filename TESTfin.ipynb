# %%
from helpers import *

torch.set_grad_enabled(False)

data, target, data_test, target_test = generate_disc_set(nb_sample=1000, show_data=True)

act_fun, criter, lr, adapt_lrd, wd, plot, plot_classif = users_choices()

# Parameters
nb_epochs = 100 #500
mini_batch_size = 50

# Modules
m1 = Modules.Linear(2,25)
m2 = Modules.Linear(25,25)
m3 = Modules.Linear(25,25)
m4 = Modules.Linear(25,2)
relu = Modules.ReLu()
tanh = Modules.Tanh() 
softmax = Modules.Softmax()

# Model
if (act_fun == 'relu'):
    model = Modules.Sequential(m1, relu, m2, tanh, m3, tanh, m4, Modules.ReLu())
if (act_fun == 'tanh'):
    model = Modules.Sequential(m1, relu, m2, tanh, m3, tanh, m4, Modules.Tanh())
if (act_fun == 'softmax'):
    model = Modules.Sequential(m1, relu, m2, tanh, m3, tanh, m4, Modules.Softmax())

# Loss criterions
if (criter == 'cross entropy'):
    criterion = Modules.CrossEntropyLoss()
if (criter == 'MSE'):
    criterion = Modules.MSE()

# Train model

losses, test_accs = train_model_SGD(model, criterion, data, target, data_test, target_test,
                                    mini_batch_size, nb_epochs, eta=lr, wd=wd,  
                                    adaptive=adapt_lrd, 
                                    plot_loss=plot, plot_points=plot_classif)
# Out:
# Do you want to choose parameters [yes/no] (if not our best model will run)?
# >no
# OK: Our best model will be run
#
#  Last layer activation function: softmax
#  Loss criterion: cross entropy
#  Learning rate: 0.05
#  Adaptive learning rate: 0.9
#  Weight decay: 1e-07
#
# 0 train_loss 694.95 test_error 51.40%
# 10 train_loss 543.91 test_error 22.30%
# 20 train_loss 478.74 test_error 18.20%
# 30 train_loss 379.79 test_error 8.20%
# 40 train_loss 356.28 test_error 2.80%
# 50 train_loss 346.95 test_error 1.50%
# 60 train_loss 346.02 test_error 1.50%
# 70 train_loss 345.95 test_error 1.50%
# 80 train_loss 345.95 test_error 1.50%
# 90 train_loss 345.96 test_error 1.50%
# 99 train_loss 345.96 test_error 1.50%

# %%
from helpers import *

torch.set_grad_enabled(False)

data, target, data_test, target_test = generate_disc_set(nb_sample=1000, show_data=True)

act_fun, criter, lr, adapt_lrd, wd, plot, plot_classif = users_choices()

# Parameters
nb_epochs = 100 #500
mini_batch_size = 50

# Modules
m1 = Modules.Linear(2,25)
m2 = Modules.Linear(25,25)
m3 = Modules.Linear(25,25)
m4 = Modules.Linear(25,2)
relu = Modules.ReLu()
tanh = Modules.Tanh() 
softmax = Modules.Softmax()

# Model
if (act_fun == 'relu'):
    model = Sequential.Sequential(m1, relu, m2, relu, m3, tanh, m4, Modules.ReLu())
if (act_fun == 'tanh'):
    model = Sequential.Sequential(m1, relu, m2, relu, m3, relu, m4, Modules.Tanh())
if (act_fun == 'softmax'):
    model = Sequential.Sequential(m1, relu, m2, relu, m3, relu, m4, Modules.Softmax())

# Loss criterions
if (criter == 'cross entropy'):
    criterion = Modules.CrossEntropyLoss()
if (criter == 'MSE'):
    criterion = Modules.MSE()

# Train model

losses, test_accs = train_model_SGD(model, criterion, data, target, data_test, target_test,
                                    mini_batch_size, nb_epochs, eta=lr, wd=wd,  
                                    adaptive=adapt_lrd, momentum=False,
                                    plot_loss=plot, plot_points=plot_classif)
# Out:
# Do you want to choose parameters [yes/no] (if not our best model will run)?
# >yes
# OK: Let's choose!
#
#
# Please choose an activation function for the last layer of the model [relu/softmax/tanh].
# >softmax
# OK: softmax is selected as activation function for the last layer.
#
#
# Please choose a loss criterion [cross entropy/MSE].
# >cross entropy
# OK: cross entropy is selected as loss criterion.
#
#
# Please choose a learning rate in the range [1e-7, 10].
# >0.05
# OK: 0.05 is selected as learning rate.
#
#
# Please choose a decay value for adaptive learning rate decay in the range [1e-3, 10] or write 'no'.
# >no
# OK: adapative learning rate decay won't be used.
#
#
# Please choose a weight decay in the range [1e-10, 1] or write 'no'.
# >no
# OK: weight decay won't be used.
#
#
# Do you want plots (train loss + test accuracy VS nb epochs) to be displayed [yes/no]?
# >yes
# OK: plots will be displayed
#
#
# Do you want classified points to be displayed [yes/no]?
# >no
# OK: plots won't be displayed
# 0 train_loss 692.71 test_error 46.60%
# 10 train_loss 525.04 test_error 19.90%
# 20 train_loss 466.44 test_error 11.20%
# 30 train_loss 441.56 test_error 28.60%
# 40 train_loss 412.40 test_error 20.50%
# 50 train_loss 422.70 test_error 6.10%
# 60 train_loss 410.29 test_error 6.10%
# 70 train_loss 414.47 test_error 13.10%
# 80 train_loss 419.26 test_error 6.40%
# 90 train_loss 423.86 test_error 4.40%
# 99 train_loss 386.51 test_error 10.70%
